# %%
using DrWatson
using Pkg
@quickactivate "toysector"
using CSV, DelimitedFiles, HypothesisTests, BSON, Distributions, Random 
using SpinModels, Optim, Parameters, CUDA, LinearAlgebra, Statistics, Printf, Flux
using BenchmarkTools, PyPlot
import StatsBase.countmap
import DrWatson.savename

include( srcdir( "fitting.jl"   ) )
include( srcdir( "toysector.jl" ) )
include( srcdir( "false_positive_funcs.jl" ) )
include( srcdir( "samplers.jl"             ) )
# Out:
# drawsamples!! (generic function with 3 methods)

# %% [markdown]
# # helper funcs

# %%
function get_froJ(J::AbstractArray{T,4} ,p::Real=2) where T<:Number
    N = size(J,2)
    froJ= [ norm(J[:,i,:,j], p) for i ∈ 1:N, j ∈ 1:N ] 
end

function get_froh(h::AbstractMatrix{T} ,p::Real=2) where T<:Number
    N = size( h,2 )
    froh = [ norm(h[:,i], p) for i ∈ 1:N ]
end

function get_froW(W::AbstractArray{T,3}, p::Real=2) where T<:Number
    P, _, N = size(W)
    froW = [ norm(W[μ,:,i],p) for μ ∈ 1:P, i ∈ 1:N  ]
end

function get_fro(A::AbstractArray, p::Real=2)
    ndims(A) == 2 && return get_froh(A,p)
    ndims(A) == 3 && return get_froW(A,p)
    ndims(A) == 4 && return get_froJ(A,p) 
end

im20(mat)= im20( mat,  begin _, ax = subplots(); ax end )
function im20(mat, ax)
    im = ax.imshow(mat )

    dimy, dimx = size(mat)
    
    stepx = round(dimx/10) == 0 ? 1 : Int(round(dimx/10))
    stepy = round(dimy/10) == 0 ? 1 : Int(round(dimy/10))
    
    # Major ticks
    ax.set_xticks(0:stepx:dimx-1)
    ax.set_yticks(0:stepy:dimy-1)

    # Labels for major ticks
    ax.set_xticklabels(1:stepx:dimx)
    ax.set_yticklabels(1:stepy:dimy)

    # Minor ticks
    ax.set_xticks(-.5:1:dimx, minor=true)
    ax.set_yticks(-.5:1:dimy, minor=true)

    # # Gridlines based on minor ticks
    # minorticks_off()
    (dimx < 50) && (dimy < 50) ? ax.grid(true, which="minor", color="k", linestyle="-", linewidth=1.5) : nothing
#     colorbar()\
    sca(ax)
    tick_params(bottom = false, left = false, which = "both")
    
    return im
end

im35(mat)= im35( mat,  begin _, ax = subplots(); ax end,  )
function im35(mat, ax, cmap="cividis", hideticklabels=false)
    im = ax.imshow(mat, cmap=cmap )

    dimy, dimx = size(mat) 
    stepx = round(dimx/10) == 0 ? 1 : Int(round(dimx/10))
    stepy = round(dimy/10) == 0 ? 1 : Int(round(dimy/10))

    ax.set_xticks([0,9,28,34])
    ax.set_yticks([0,9,28,34])
    ax.set_xticklabels( [1,10,29,35],  fontsize=16 )
    ax.set_yticklabels( [1,10,29,35],  fontsize=16 )
    
    ax.tick_params(bottom = false, left = false, which = "both")
    
    ax.set_xticks(-.5:1:dimx, minor=true)
    ax.set_yticks(-.5:1:dimy, minor=true)
    (dimx < 50) && (dimy < 50) ? ax.grid(true, which="minor", 
        color="k", linestyle="-", linewidth=0.5) : nothing
    
    
    if hideticklabels == false
        ax.xaxis.set_tick_params(labeltop=true)
        ax.xaxis.set_tick_params(labelbottom=false)
    else
        ax.yaxis.set_tick_params(labelleft=false)
        ax.xaxis.set_tick_params(labelbottom=false)
    end
    
   
    
    # Major ticks
    # ax.set_xticks(0:stepx:dimx-1)
    # ax.set_yticks(0:stepy:dimy-1)
    # # Labels for major ticks
    # ax.set_xticklabels(1:stepx:dimx)
    # ax.set_yticklabels(1:stepy:dimy)  
    
    ax.vlines([10,28].-0.5, -0.5, dimy-0.5, colors="white", linewidth=2)
    ax.hlines([10,28].-0.5, -0.5, dimx-0.5, colors="white", linewidth=2)
    return im
end
# Out:
# im35 (generic function with 4 methods)

# %% [markdown]
# # specify models to fit

# %%
folds = 5
seed = 123
Random.seed!(seed)
calc_f_pos = false
nsamples_for_fpos = 10_000;
calc_H = false
# Out:
# false

# %%
samples_to_fit_all = Dict{Symbol, Any}(
    :M => [500], #nsamples
#     :T_sec => [0.2, 0.25, 0.3, 0.4, 0.5, 0.6]  
    :T_sec => [1.,0.4, 0.2],
    :m => [1,2,3]
    )

modls = [:Pairwise]# , :RBM]#, :SRBM]

params_sets = Dict{Symbol,Any}(
        :Pairwise => Dict{Symbol, Any}(
        :reg_J => [(10f0^log10λ, 2) for log10λ ∈ -8:1],
        :reg_h => [(10f0^log10λ, 2) for log10λ ∈ 2:2],
        :epochs => 20_000,
        :showevery => 500,
        :progTol => 10^-6
    )
     # ,
     #     :RBM => Dict{Symbol, Any}(
     #     :reg_W => [(10f0^log10λ, 2) for log10λ ∈ -8:-1],
     #     :reg_h => [(10f0^log10λ, 2) for log10λ ∈ -4:2],
     #     :P => [10,20,30,40,50],
     #     :epochs => 20_000,
     #     :showevery => 500,
     #     :progTol => 10^-6
     # )
#     ,
#     :SRBM => Dict{Symbol, Any}(
#         :reg_J => [(10f0^log10λ, 2) for log10λ ∈ -6:-1],
#         :reg_W => [(10f0^log10λ, 2) for log10λ ∈ -8:-1],
#         :reg_h => [(10f0^log10λ, 2) for log10λ ∈ -4:2],
#         :P => collect(10:20:50),
#         :epochs => 20_000,
#         :showevery => 50,
#         :progTol => 10^-6
#     )
)

samples_to_fit_dict_list = dict_list(samples_to_fit_all)
# Out:
# 9-element Vector{Dict{Symbol, Real}}:
#  Dict(:m => 1, :M => 500, :T_sec => 1.0)
#  Dict(:m => 2, :M => 500, :T_sec => 1.0)
#  Dict(:m => 3, :M => 500, :T_sec => 1.0)
#  Dict(:m => 1, :M => 500, :T_sec => 0.4)
#  Dict(:m => 2, :M => 500, :T_sec => 0.4)
#  Dict(:m => 3, :M => 500, :T_sec => 0.4)
#  Dict(:m => 1, :M => 500, :T_sec => 0.2)
#  Dict(:m => 2, :M => 500, :T_sec => 0.2)
#  Dict(:m => 3, :M => 500, :T_sec => 0.2)

# %% [markdown]
# # fit the models for each dataset

# %%
for k in 1:length(samples_to_fit_dict_list)


samples_to_fit_info=samples_to_fit_dict_list[k]
sampledir(args...) = datadir("toysector_q=5", 
    "nsamples=$(samples_to_fit_info[:M])", args...)

z = BSON.load(
    sampledir( @sprintf("sector_temp=%.2f_m=%i_samples.bson", 
                samples_to_fit_info[:T_sec], samples_to_fit_info[:m]) ) 
    )[:samples];
z = Float32.(z)
q,N,_=size(z)

### make into cuda array if possible
z = CUDA.functional() ? cu(z) : z
@printf "%s\n" "Array type: $(typeof(z))"
𝕏 = kfold( Float32.(z), folds )

fitsdir(args...) = sampledir("fitted_models", 
    @sprintf("sector_temp=%.2f_m=%i", 
        samples_to_fit_info[:T_sec], samples_to_fit_info[:m]), 
    args...)

sweep_dicts = Dict{Symbol, Any}()
for mdl in modls
    sweep_dicts[mdl] = dict_list( params_sets[mdl] )
end
for mdl in modls
    mdldir(args...) = fitsdir(string(mdl), args...)
    isdir(mdldir()) || mkpath(mdldir())
    
    println(mdldir())
    swp_ds_string = mdldir( string(mdl)*"_all_results.bson")
    
    ### do hyperparam sweep
    swp_ds = sweep_dicts[mdl] #alias
    @printf "\n"
    @printf "Begin sweep of %s model\n" string(mdl)
    for d in sweep_dicts[mdl]
        @printf "\n"
        @printf "-----------------------------------------------\n"
        @printf "%s\n" savename(d)
	    if isfile(mdldir(savename(d)*".bson"))
            merge!(d, BSON.load(mdldir(savename(d)*".bson"))[:d])
            @printf "model alrealy fit. skipping\n" 
            continue
        end
        
        @printf "-----------------------------------------------\n"
        ### 5 fold fit
        θ = mdl == :Pairwise ? Pairwise(; q=q , N=N, similarto=z) : eval(mdl)(q=q,N=N,P=d[:P], similarto=z)
        SpinModels.random!(θ)
        _, 𝕋, 𝕍 = kfold_sgdfit!(θ, 𝕏; d... )
        ### fit all data to model
        SpinModels.random!(θ)
        @printf "train on whole dataset\n"
        intrace = sgdfit!(θ, z; d... )
        inloss = intrace[:f_training][end] 
        
        ###calculate false_pos_rate
        false_pos_rate_entropy = ( calc_f_pos || (calc_H && (N*log(q)) < 21. ) ) ? get_f_pos_rate( θsec, θ, 
            sec_energy_buffer, all_states_buffer, nsamples_for_fpos ) : (nothing, nothing)
        false_pos_rate = false_pos_rate_entropy[1]
        fit_entropy = false_pos_rate_entropy[2]
        
        ### put results in dictionary
        results = Dict{Symbol, Any}( :𝕍 => 𝕍, :𝕋 => 𝕋, :intrace => intrace, :inloss => inloss, 
             :mean𝕍 => mean(𝕍), :std𝕍 => std(𝕍), :false_pos_rate => false_pos_rate, 
                :fit_entropy => fit_entropy, :true_entropy => nothing)  
        merge!(d, results)
        
        
        ### save results
        BSON.@save mdldir(savename(d)*".bson") d
        vecθ = collect(veccopy(θ))
        BSON.@save mdldir(savename(d)*"_model.bson") vecθ
    end
#     #also save the vector of dictionaries with results
    BSON.@save swp_ds_string swp_ds
end
    
    
end
# Out:
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=1/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# model alrealy fit. skipping
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=2/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# model alrealy fit. skipping
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=3/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# model alrealy fit. skipping
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=1/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  190.127731    1.006137     0
#   500    0.348628    0.303124     1
#  1000    0.257555    0.257547     2
#  1500    0.235070    0.235058     2
#  2000    0.219623    0.219605     3
#  2500    0.207223    0.207200     4
#  3000    0.196736    0.196706     5
#  3500    0.187363    0.187326     6
#  4000    0.179035    0.178991     6
#  4500    0.171491    0.171437     7
#  5000    0.164705    0.164641     8
#  5500    0.158509    0.158434     9
#  6000    0.152923    0.152836    10
#  6500    0.147910    0.147812    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  190.606583    1.005757     0
#   500    0.379541    0.297351     1
#  1000    0.250227    0.250218     2
#  1500    0.226827    0.226814     2
#  2000    0.210776    0.210758     3
#  2500    0.198119    0.198095     4
#  3000    0.187512    0.187482     5
#  3500    0.178128    0.178091     6
#  4000    0.169831    0.169785     6
#  4500    0.162401    0.162346     7
#  5000    0.155623    0.155558     8
#  5500    0.149582    0.149506     9
#  6000    0.144141    0.144053     9
#  6500    0.139182    0.139082    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  136.619858    1.005165     0
#   500    0.310198    0.300380     1
#  1000    0.253683    0.253675     2
#  1500    0.230376    0.230364     2
#  2000    0.214575    0.214557     3
#  2500    0.202073    0.202050     4
#  3000    0.191449    0.191419     5
#  3500    0.182219    0.182181     6
#  4000    0.173916    0.173871     6
#  4500    0.166387    0.166332     7
#  5000    0.159694    0.159629     8
#  5500    0.153693    0.153617     9
#  6000    0.148133    0.148046     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  163.705505    1.003638     0
#   500    0.303758    0.298229     1
#  1000    0.252045    0.252037     2
#  1500    0.229344    0.229332     2
#  2000    0.214013    0.213996     3
#  2500    0.201913    0.201890     4
#  3000    0.191650    0.191620     5
#  3500    0.182577    0.182541     6
#  4000    0.174478    0.174433     6
#  4500    0.167158    0.167105     7
#  5000    0.160504    0.160441     8
#  5500    0.154461    0.154388     9
#  6000    0.148950    0.148864    10
#  6500    0.144066    0.143968    11
#  7000    0.139533    0.139423    12
#  7500    0.135441    0.135317    13
#  8000    0.131727    0.131587    14
#  8500    0.128294    0.128140    15
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  171.891876    1.006369     0
#   500    0.448604    0.301107     1
#  1000    0.255201    0.255164     2
#  1500    0.232645    0.232633     3
#  2000    0.217249    0.217232     3
#  2500    0.204780    0.204757     4
#  3000    0.194350    0.194321     5
#  3500    0.185107    0.185070     6
#  4000    0.176836    0.176792     6
#  4500    0.169305    0.169252     7
#  5000    0.162567    0.162504     8
#  5500    0.156440    0.156365     9
#  6000    0.150928    0.150842    10
#  6500    0.145867    0.145768    11
#  7000    0.141317    0.141205    11
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  156.593231    1.003293     0
#   500    0.409773    0.378618     1
#  1000    0.341603    0.341597     2
#  1500    0.324724    0.324715     3
#  2000    0.313981    0.313969     4
#  2500    0.305890    0.305874     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  190.163910    1.005443     0
#   500    0.497016    0.303152     1
#  1000    0.257723    0.257586     2
#  1500    0.235265    0.235144     2
#  2000    0.219916    0.219745     3
#  2500    0.207633    0.207406     4
#  3000    0.197110    0.196819     5
#  3500    0.187963    0.187601     6
#  4000    0.179796    0.179354     6
#  4500    0.172422    0.171892     7
#  5000    0.165774    0.165148     8
#  5500    0.159715    0.158986     9
#  6000    0.154293    0.153450    10
#  6500    0.149345    0.148383    11
#  7000    0.144985    0.143896    12
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  197.577301    1.003139     0
#   500    0.321559    0.297109     1
#  1000    0.250196    0.250118     2
#  1500    0.226983    0.226860     3
#  2000    0.210935    0.210760     4
#  2500    0.198388    0.198156     5
#  3000    0.187758    0.187461     6
#  3500    0.178505    0.178135     7
#  4000    0.170270    0.169818     8
#  4500    0.162911    0.162370     9
#  5000    0.156345    0.155707    10
#  5500    0.150298    0.149554    11
#  6000    0.145014    0.144158    12
#  6500    0.140272    0.139296    13
#  7000    0.135901    0.134799    14
#  7500    0.131930    0.130696    15
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  172.038315    1.004626     0
#   500    0.360900    0.300485     1
#  1000    0.253778    0.253700     2
#  1500    0.230633    0.230510     2
#  2000    0.214833    0.214659     3
#  2500    0.202423    0.202192     4
#  3000    0.191944    0.191648     5
#  3500    0.182992    0.182623     6
#  4000    0.174836    0.174387     6
#  4500    0.167476    0.166938     7
#  5000    0.160807    0.160171     8
#  5500    0.154768    0.154028     9
#  6000    0.149420    0.148565     9
#  6500    0.144577    0.143603    10
#  7000    0.140172    0.139071    11
#  7500    0.136220    0.134985    12
#  8000    0.132609    0.131236    13
#  8500    0.129367    0.127847    14
#  9000    0.126375    0.124704    15
#  9500    0.123696    0.121874    16
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  195.073151    1.005915     0
#   500    0.355902    0.298288     1
#  1000    0.252253    0.252175     2
#  1500    0.229610    0.229487     2
#  2000    0.214159    0.213987     3
#  2500    0.202207    0.201979     4
#  3000    0.192050    0.191759     5
#  3500    0.183102    0.182740     6
#  4000    0.175102    0.174661     6
#  4500    0.167857    0.167329     7
#  5000    0.161342    0.160719     8
#  5500    0.155441    0.154715     9
#  6000    0.150146    0.149309    10
#  6500    0.145213    0.144259    11
#  7000    0.140853    0.139773    11
#  7500    0.136902    0.135691    12
#  8000    0.133306    0.131956    13
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  206.911285    1.007145     0
#   500    0.352188    0.301186     1
#  1000    0.255436    0.255358     2
#  1500    0.232858    0.232736     2
#  2000    0.217415    0.217243     3
#  2500    0.205199    0.204970     4
#  3000    0.194797    0.194505     5
#  3500    0.185648    0.185285     6
#  4000    0.177548    0.177104     6
#  4500    0.170277    0.169746     7
#  5000    0.163670    0.163044     8
#  5500    0.157656    0.156927     9
#  6000    0.152315    0.151475    10
#  6500    0.147462    0.146505    10
#  7000    0.142966    0.141885    11
#  7500    0.138962    0.137748    12
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  207.126450    1.005837     0
#   500    0.516879    0.378901     1
#  1000    0.341826    0.341745     2
#  1500    0.324871    0.324782     3
#  2000    0.314173    0.314053     3
#  2500    0.306017    0.305863     4
#  3000    0.299488    0.299299     5
#  3500    0.293647    0.293419     6
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  168.775879    1.006612     0
#   500    0.310239    0.303314     1
#  1000    0.258634    0.257868     2
#  1500    0.236834    0.235636     2
#  2000    0.222064    0.220386     3
#  2500    0.210476    0.208260     4
#  3000    0.200698    0.197883     5
#  3500    0.192321    0.188842     6
#  4000    0.185114    0.180908     6
#  4500    0.178768    0.173778     7
#  5000    0.173340    0.167517     8
#  5500    0.168584    0.161889     9
#  6000    0.164477    0.156876    10
#  6500    0.160891    0.152360    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  172.799438    1.005276     0
#   500    0.307544    0.297418     1
#  1000    0.251205    0.250427     2
#  1500    0.228460    0.227238     2
#  2000    0.213142    0.211424     3
#  2500    0.201350    0.199080     4
#  3000    0.191564    0.188680     5
#  3500    0.183247    0.179687     6
#  4000    0.176067    0.171772     6
#  4500    0.169730    0.164641     7
#  5000    0.164305    0.158376     8
#  5500    0.159591    0.152782     9
#  6000    0.155494    0.147776    10
#  6500    0.151946    0.143297    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  172.414352    1.003339     0
#   500    0.369156    0.300380     1
#  1000    0.254591    0.253812     2
#  1500    0.232115    0.230895     2
#  2000    0.216901    0.215187     3
#  2500    0.205275    0.203013     4
#  3000    0.195692    0.192820     5
#  3500    0.187397    0.183853     6
#  4000    0.180272    0.175996     6
#  4500    0.174004    0.168938     7
#  5000    0.168514    0.162608     8
#  5500    0.163889    0.157106     9
#  6000    0.159812    0.152123    10
#  6500    0.156307    0.147691    10
#  7000    0.153368    0.143813    11
#  7500    0.150757    0.140265    12
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  193.326599    1.005762     0
#   500    0.331276    0.298495     1
#  1000    0.253103    0.252329     2
#  1500    0.231027    0.229814     2
#  2000    0.216296    0.214599     3
#  2500    0.205017    0.202784     4
#  3000    0.195756    0.192931     5
#  3500    0.187854    0.184380     6
#  4000    0.180762    0.176579     6
#  4500    0.174601    0.169651     7
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  187.659927    1.005949     0
#   500    0.623035    0.301193     1
#  1000    0.256610    0.255554     2
#  1500    0.234309    0.233099     2
#  2000    0.219604    0.217910     3
#  2500    0.208063    0.205831     4
#  3000    0.198528    0.195698     5
#  3500    0.190316    0.186825     6
#  4000    0.183294    0.179081     6
#  4500    0.177027    0.172039     7
#  5000    0.171674    0.165862     8
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  147.825974    1.006302     0
#   500    0.399373    0.378983     1
#  1000    0.342459    0.341871     2
#  1500    0.326062    0.325181     3
#  2000    0.315651    0.314467     4
#  2500    0.307986    0.306482     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  143.745514    1.003729     0
#   500    0.310075    0.304255     1
#  1000    0.267490    0.260222     2
#  1500    0.250553    0.239667     2
#  2000    0.240727    0.226287     3
#  2500    0.234411    0.216510     4
#  3000    0.230034    0.208827     5
#  3500    0.227080    0.202799     6
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  181.407043    1.004521     0
#   500    0.330805    0.298493     1
#  1000    0.260344    0.252970     2
#  1500    0.242523    0.231434     2
#  2000    0.232331    0.217570     3
#  2500    0.225869    0.207547     4
#  3000    0.221550    0.199859     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  142.102051    1.004290     0
#   500    0.308250    0.301699     1
#  1000    0.263710    0.256352     2
#  1500    0.246195    0.235126     2
#  2000    0.236030    0.221314     3
#  2500    0.229818    0.211579     4
#  3000    0.225539    0.203968     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  220.165558    1.006142     0
#   500    0.487395    0.299511     1
#  1000    0.262036    0.254650     2
#  1500    0.244865    0.233853     2
#  2000    0.235115    0.220528     3
#  2500    0.229082    0.211057     4
#  3000    0.225028    0.203780     5
#  3500    0.222219    0.198010     6
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  193.114304    1.005692     0
#   500    0.378145    0.302401     1
#  1000    0.265302    0.257970     2
#  1500    0.248217    0.237238     2
#  2000    0.238549    0.223999     3
#  2500    0.232342    0.214346     4
#  3000    0.228019    0.206753     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  203.597092    1.006795     0
#   500    0.530016    0.379772     1
#  1000    0.349279    0.343636     2
#  1500    0.336042    0.327904     3
#  2000    0.328771    0.318294     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  198.850052    1.006893     0
#   500    0.411697    0.315566     1
#  1000    0.330129    0.283710     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  203.813782    1.005457     0
#   500    0.458895    0.309767     1
#  1000    0.323981    0.276779     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  192.375198    1.006078     0
#   500    0.388214    0.313172     1
#  1000    0.327278    0.280301     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  167.408859    1.005783     0
#   500    0.411240    0.310844     1
#  1000    0.325451    0.278446     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  161.195419    1.005145     0
#   500    0.373405    0.313741     1
#  1000    0.328455    0.281701     2
#  1500    0.326371    0.273005     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  169.769379    1.005669     0
#   500    0.459381    0.388440     1
#  1000    0.399140    0.360831     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  197.390030    1.007897     0
#   500    0.671266    0.407519     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  158.120483    1.005747     0
#   500    0.532964    0.403043     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  165.516113    1.004084     0
#   500    0.618526    0.406080     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  166.113739    1.006587     0
#   500    0.536641    0.404015     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  205.236923    1.005611     0
#   500    0.616321    0.406338     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  172.122375    1.005311     0
#   500    0.569084    0.465351     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  154.022018    1.004043     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  167.263870    1.004198     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  194.159409    1.004255     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  157.132278    1.006247     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  140.749283    1.005580     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  202.345901    1.004859     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  175.144257    1.005578     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  175.572739    1.003603     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  156.385727    1.004472     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  195.315582    1.006059     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  186.459412    1.005649     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  159.455566    1.003042     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  217.307785    1.005987     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  161.357880    1.004554     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  180.234924    1.005973     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  132.422684    1.003918     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  148.066132    1.003338     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  186.661652    1.005918     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  217.609787    1.007350     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  219.040588    1.005767     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  149.703537    1.005706     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  173.008240    1.005504     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  185.014130    1.006538     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  202.779541    1.005981     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=2/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# model alrealy fit. skipping
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=3/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# model alrealy fit. skipping
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# model alrealy fit. skipping
# Array type: Array{Float32, 3}
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.20_m=1/Pairwise
#
# Begin sweep of Pairwise model
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-8.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  142.564453    1.004545     0
#   500    0.321518    0.319086     1
#  1000    0.281421    0.281415     2
#  1500    0.262573    0.262563     2
#  2000    0.249279    0.249265     3
#  2500    0.238694    0.238675     4
#  3000    0.229665    0.229641     5
#  3500    0.221591    0.221559     6
#  4000    0.214286    0.214248     6
#  4500    0.207727    0.207683     7
#  5000    0.201798    0.201745     8
#  5500    0.196307    0.196246     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  170.711227    1.005396     0
#   500    0.344049    0.318489     1
#  1000    0.280788    0.280782     2
#  1500    0.261949    0.261938     2
#  2000    0.248841    0.248827     3
#  2500    0.238315    0.238296     4
#  3000    0.229398    0.229373     5
#  3500    0.221414    0.221384     6
#  4000    0.214320    0.214283     6
#  4500    0.207830    0.207786     7
#  5000    0.201823    0.201771     8
#  5500    0.196346    0.196285     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  184.077255    1.004566     0
#   500    0.329783    0.320183     1
#  1000    0.282079    0.282072     2
#  1500    0.263112    0.263102     2
#  2000    0.249958    0.249943     3
#  2500    0.239568    0.239549     4
#  3000    0.230608    0.230584     5
#  3500    0.222789    0.222759     6
#  4000    0.215789    0.215752     6
#  4500    0.209447    0.209403     7
#  5000    0.203637    0.203586     8
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  175.535278    1.004279     0
#   500    0.334780    0.323141     1
#  1000    0.286001    0.285995     2
#  1500    0.267509    0.267499     2
#  2000    0.254459    0.254445     3
#  2500    0.243747    0.243728     4
#  3000    0.234704    0.234680     5
#  3500    0.226740    0.226710     6
#  4000    0.219534    0.219497     7
#  4500    0.213024    0.212980     7
#  5000    0.207054    0.207002     8
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  163.950180    1.003489     0
#   500    0.358725    0.316935     1
#  1000    0.278492    0.278484     2
#  1500    0.259138    0.259127     2
#  2000    0.245565    0.245550     3
#  2500    0.234866    0.234846     4
#  3000    0.225660    0.225635     5
#  3500    0.217628    0.217597     6
#  4000    0.210337    0.210299     6
#  4500    0.203789    0.203744     7
#  5000    0.197827    0.197774     8
#  5500    0.192342    0.192280     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  172.839935    1.004246     0
#   500    0.433872    0.393224     1
#  1000    0.363977    0.363972     2
#  1500    0.350256    0.350248     3
#  2000    0.340990    0.340980     4
#  2500    0.333637    0.333625     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-7.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  168.499908    1.004650     0
#   500    0.349600    0.318966     1
#  1000    0.281406    0.281341     2
#  1500    0.262602    0.262501     2
#  2000    0.249497    0.249355     3
#  2500    0.238952    0.238764     4
#  3000    0.229945    0.229704     5
#  3500    0.222121    0.221821     6
#  4000    0.215065    0.214699     6
#  4500    0.208599    0.208161     7
#  5000    0.202828    0.202311     8
#  5500    0.197362    0.196761     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  186.836273    1.005174     0
#   500    0.382075    0.318581     1
#  1000    0.280928    0.280862     2
#  1500    0.262222    0.262122     2
#  2000    0.249247    0.249106     3
#  2500    0.238788    0.238600     4
#  3000    0.229927    0.229687     5
#  3500    0.222160    0.221862     6
#  4000    0.215057    0.214695     6
#  4500    0.208617    0.208184     7
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  151.172455    1.004761     0
#   500    0.333362    0.320151     1
#  1000    0.282199    0.282135     2
#  1500    0.263334    0.263233     2
#  2000    0.250137    0.249995     3
#  2500    0.239718    0.239530     4
#  3000    0.230907    0.230668     5
#  3500    0.223196    0.222899     6
#  4000    0.216226    0.215865     6
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  192.743683    1.006073     0
#   500    0.442923    0.323250     1
#  1000    0.286047    0.285972     2
#  1500    0.267453    0.267354     2
#  2000    0.254489    0.254350     3
#  2500    0.243885    0.243700     4
#  3000    0.235046    0.234808     5
#  3500    0.227117    0.226821     6
#  4000    0.219956    0.219596     7
#  4500    0.213516    0.213084     7
#  5000    0.207620    0.207112     8
#  5500    0.202298    0.201706     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  194.539459    1.003457     0
#   500    0.353667    0.316968     1
#  1000    0.278637    0.278571     2
#  1500    0.259385    0.259283     2
#  2000    0.245884    0.245740     3
#  2500    0.235223    0.235031     4
#  3000    0.226064    0.225819     5
#  3500    0.217986    0.217680     6
#  4000    0.210845    0.210473     7
#  4500    0.204445    0.204000     7
#  5000    0.198537    0.198012     8
#  5500    0.193174    0.192563     9
#  6000    0.188251    0.187547    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  168.764236    1.005471     0
#   500    0.504938    0.393046     1
#  1000    0.364142    0.364082     2
#  1500    0.350323    0.350251     3
#  2000    0.341015    0.340917     4
#  2500    0.333713    0.333587     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-6.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  191.517822    1.007113     0
#   500    0.353698    0.319245     1
#  1000    0.282260    0.281617     2
#  1500    0.263873    0.262875     3
#  2000    0.251172    0.249776     3
#  2500    0.241281    0.239439     4
#  3000    0.233044    0.230706     5
#  3500    0.225898    0.223013     6
#  4000    0.219570    0.216091     7
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  192.923965    1.006725     0
#   500    0.510080    0.318658     1
#  1000    0.281765    0.281080     2
#  1500    0.263472    0.262479     2
#  2000    0.250956    0.249568     3
#  2500    0.241192    0.239363     4
#  3000    0.232936    0.230615     5
#  3500    0.225856    0.222992     6
#  4000    0.219637    0.216184     7
#  4500    0.214116    0.210027     7
#  5000    0.209178    0.204412     8
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  152.238480    1.003866     0
#   500    0.332360    0.320201     1
#  1000    0.282775    0.282132     2
#  1500    0.264457    0.263458     2
#  2000    0.251882    0.250487     3
#  2500    0.242167    0.240330     4
#  3000    0.234041    0.231717     5
#  3500    0.226961    0.224102     6
#  4000    0.220960    0.217521     7
#  4500    0.215547    0.211487     7
#  5000    0.210717    0.205998     8
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  170.471115    1.005015     0
#   500    0.388901    0.323257     1
#  1000    0.286923    0.286290     2
#  1500    0.268653    0.267671     2
#  2000    0.256170    0.254796     3
#  2500    0.246243    0.244429     4
#  3000    0.237967    0.235664     5
#  3500    0.230802    0.227956     6
#  4000    0.224644    0.221209     7
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  159.719543    1.005292     0
#   500    0.357982    0.317098     1
#  1000    0.279376    0.278722     2
#  1500    0.260662    0.259645     2
#  2000    0.247679    0.246256     3
#  2500    0.237520    0.235642     4
#  3000    0.229020    0.226637     5
#  3500    0.221857    0.218918     6
#  4000    0.215623    0.212077     7
#  4500    0.210101    0.205905     7
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  173.099045    1.004402     0
#   500    0.410722    0.393259     1
#  1000    0.364725    0.364242     2
#  1500    0.351374    0.350658     3
#  2000    0.342337    0.341374     4
#  2500    0.335455    0.334225     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  185.622650    1.004763     0
#   500    0.334952    0.320125     1
#  1000    0.289751    0.283647     2
#  1500    0.275486    0.266412     2
#  2000    0.267003    0.254974     3
#  2500    0.261473    0.246546     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  179.940491    1.004403     0
#   500    0.350644    0.319344     1
#  1000    0.289047    0.282955     2
#  1500    0.274761    0.265708     2
#  2000    0.266603    0.254610     3
#  2500    0.261120    0.246259     4
#  3000    0.257498    0.239901     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  155.133820    1.004171     0
#   500    0.336667    0.321052     1
#  1000    0.290377    0.284256     2
#  1500    0.275970    0.266878     2
#  2000    0.267602    0.255570     3
#  2500    0.262237    0.247338     4
#  3000    0.258494    0.240866     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  216.990829    1.005988     0
#   500    0.533714    0.324251     1
#  1000    0.294307    0.288277     2
#  1500    0.280099    0.271169     2
#  2000    0.271705    0.259864     3
#  2500    0.266379    0.251694     4
#  3000    0.262515    0.245087     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  164.197937    1.004769     0
#   500    0.441157    0.317999     1
#  1000    0.287059    0.280848     2
#  1500    0.272357    0.263109     2
#  2000    0.263764    0.251493     3
#  2500    0.258069    0.242834     4
#  3000    0.254239    0.236186     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  175.059692    1.005719     0
#   500    0.453746    0.394046     1
#  1000    0.370348    0.365732     2
#  1500    0.359611    0.353005     3
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  152.433655    1.004472     0
#   500    0.361665    0.329351     1
#  1000    0.342572    0.302964     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# ...
#  1500    0.271034    0.270005     3
#  2000    0.257897    0.256456     3
#  2500    0.247590    0.245687     4
#  3000    0.239037    0.236620     5
#  3500    0.231643    0.228662     6
#  4000    0.225227    0.221633     7
#  4500    0.219566    0.215311     8
#  5000    0.214541    0.209586     9
#  5500    0.210097    0.204405     9
#  6000    0.206163    0.199706    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  169.101105    1.004065     0
#   500    0.330239    0.322681     1
#  1000    0.285546    0.284888     2
#  1500    0.266720    0.265695     3
#  2000    0.253371    0.251932     3
#  2500    0.242814    0.240909     4
#  3000    0.233859    0.231431     5
#  3500    0.226345    0.223341     6
#  4000    0.219749    0.216117     7
#  4500    0.213978    0.209673     8
#  5000    0.208966    0.203946     8
#  5500    0.204528    0.198759     9
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  164.279282    1.003380     0
#   500    0.577590    0.320344     1
#  1000    0.281843    0.281083     2
#  1500    0.262324    0.261278     3
#  2000    0.249016    0.247548     3
#  2500    0.238705    0.236765     4
#  3000    0.230126    0.227663     5
#  3500    0.222863    0.219827     6
#  4000    0.216564    0.212908     7
#  4500    0.211016    0.206696     8
#  5000    0.206039    0.201010     8
#  5500    0.201694    0.195921     9
#  6000    0.197821    0.191276    10
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  179.731537    1.005797     0
#   500    0.463674    0.396888     1
#  1000    0.367085    0.366584     2
#  1500    0.353126    0.352381     3
#  2000    0.343671    0.342666     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-5.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  165.807358    1.004008     0
#   500    0.581479    0.326682     1
#  1000    0.296342    0.290031     2
#  1500    0.281564    0.272295     2
#  2000    0.272789    0.260462     3
#  2500    0.267026    0.251688     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  180.577423    1.006954     0
#   500    0.384633    0.319313     1
#  1000    0.288237    0.281989     2
#  1500    0.273488    0.264176     3
#  2000    0.264974    0.252621     3
#  2500    0.259246    0.243911     4
#  3000    0.255445    0.237276     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  165.775101    1.003969     0
#   500    0.358302    0.328725     1
#  1000    0.297746    0.291470     2
#  1500    0.282874    0.273523     2
#  2000    0.274115    0.261696     3
#  2500    0.268454    0.253038     4
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  192.724762    1.004965     0
#   500    0.344660    0.323741     1
#  1000    0.293240    0.286990     2
#  1500    0.278512    0.269197     3
#  2000    0.269609    0.257229     3
#  2500    0.263712    0.248296     4
#  3000    0.259669    0.241327     5
#  3500    0.256774    0.235683     6
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  171.607864    1.004676     0
#   500    0.332597    0.321383     1
#  1000    0.289682    0.283347     2
#  1500    0.274492    0.265005     2
#  2000    0.265706    0.253084     3
#  2500    0.259941    0.244261     4
#  3000    0.256062    0.237475     5
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  145.184158    1.004908     0
#   500    0.424337    0.397515     1
#  1000    0.372923    0.368139     2
#  1500    0.361528    0.354648     3
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-4.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  173.936310    1.006786     0
#   500    0.380286    0.336423     1
#  1000    0.349814    0.309850     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  189.286438    1.004411     0
#   500    0.507759    0.328839     1
#  1000    0.342272    0.301847     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  168.839096    1.005249     0
#   500    0.373782    0.338178     1
#  1000    0.352025    0.311516     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  139.730713    1.002555     0
#   500    0.361087    0.333233     1
#  1000    0.347200    0.306883     2
#  1500    0.345297    0.299501     3
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  149.869446    1.005881     0
#   500    0.362757    0.331002     1
#  1000    0.344439    0.303616     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  207.117538    1.008024     0
#   500    0.588276    0.405045     1
#  1000    0.415483    0.382633     2
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-3.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  133.737411    1.002747     0
#   500    0.506684    0.415506     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  195.914688    1.006475     0
#   500    0.812165    0.408856     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  166.572098    1.007064     0
#   500    0.527504    0.418865     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  202.147247    1.006864     0
#   500    1.041637    0.413152     1
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  192.480286    1.006004     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  171.754044    1.006082     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-2.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  155.044434    1.005438     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  144.163528    1.005596     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  168.721115    1.003923     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  205.225891    1.007457     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  177.536575    1.003371     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  165.952530    1.005767     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e-1.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  185.093826    1.006452     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  163.223831    1.007024     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  188.750534    1.006772     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  182.931992    1.006232     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  156.249741    1.006270     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  181.022583    1.004988     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e0.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  190.185547    1.004852     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  185.073074    1.007845     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  216.315842    1.005626     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  176.039642    1.004425     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  167.229691    1.003713     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  187.217422    1.006246     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
#
# -----------------------------------------------
# L2_regh=1e2.0_regJ=1e1.0
# -----------------------------------------------
# k-fold: 1 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  182.445419    1.004172     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 2 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  179.610474    1.005347     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 3 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  179.510559    1.003654     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 4 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  191.075134    1.004384     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# k-fold: 5 of 5
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  199.397842    1.005874     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------
# train on whole dataset
# ------------------ Begin SGD ------------------
# epoch  reg. loss   train loss  time
# -----  ----------  ----------  ----
#     0  163.015762    1.004358     0
# rel change in bare loss below progTol 1.0e-6
# ------------------- End SGD -------------------

# %% [markdown]
# # find best model for each dataset

# %%
for k in 1:length(samples_to_fit_dict_list)

    samples_to_fit_info=samples_to_fit_dict_list[k]
    sampledir(args...) = datadir("toysector_q=5", 
        "nsamples=$(samples_to_fit_info[:M])", args...)


    fitsdir(args...) = sampledir("fitted_models", 
        @sprintf("sector_temp=%.2f_m=%i", 
            samples_to_fit_info[:T_sec], samples_to_fit_info[:m]), 
        args...)
    
    sweep_dicts = Dict{Symbol, Any}()

    for mdl in modls
        mdldir(args...) = fitsdir(string(mdl), args...)

        println(mdldir())
        swp_ds_string = mdldir( string(mdl)*"_all_results.bson")

        ### do hyperparam sweep
        # swp_ds = sweep_dicts[mdl] #alias

        BSON.@load swp_ds_string swp_ds

        # @show keys(swp_ds[1])
        
        sweep_dicts[mdl]=swp_ds
    end
    
    losses_pw   = pull_from_sweep(sweep_dicts[:Pairwise], 
    [:reg_h, :reg_J, :mean𝕍] 
    )
    best_idx_pw = findmin(losses_pw[:,end])[2]
    best_pw_reg_h, best_pw_reg_J, _ = losses_pw[best_idx_pw, :]

    ### put that model in accessible part of folder
    best_model_dict_pw=filter( d -> ( (d[:reg_J] == best_pw_reg_J) && (d[:reg_h] == best_pw_reg_h) ) , sweep_dicts[:Pairwise] )[1]
    cp( fitsdir("Pairwise", savename(best_model_dict_pw)*"_model.bson") , fitsdir(savename(best_model_dict_pw)*"_bestmodel.bson") ; force=true) 
    cp( fitsdir("Pairwise", savename(best_model_dict_pw)*".bson") , fitsdir(savename(best_model_dict_pw)*"_best.bson") ; force = true) 
end
# Out:
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=1/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=2/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=1.00_m=3/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=1/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=2/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.40_m=3/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :frac_func, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.20_m=1/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.20_m=2/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
# /Users/pfields/Git/toysector/data/toysector_q=5/nsamples=500/fitted_models/sector_temp=0.20_m=3/Pairwise
# keys(swp_ds[1]) = [:progTol, :true_entropy, :false_pos_rate, :reg_J, :fit_entropy, :reg_h, :intrace, :𝕍, :std𝕍, :mean𝕍, :showevery, :epochs, :𝕋, :inloss]
